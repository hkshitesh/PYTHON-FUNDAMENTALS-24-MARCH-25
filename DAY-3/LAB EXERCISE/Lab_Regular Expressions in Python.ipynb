# %% [markdown]
# # **2. The re Module**
#
# ---
#
#
# The re module is used to work with regular expressions in Python. It provides various functions for matching, searching, and replacing text.
#
# Key Functions in the re Module:
# # **1.	re.match(pattern, string):**
#
# ---
#
#
# o	Tries to match the pattern at the beginning of the string.
#
# o	Returns a match object if found, or None if not.
#
# o	Example:

# %%
import re
result = re.match(r'abc', 'abcdef')
if result:
    print("Match found:", result.group())
else:
    print("No match.")
# Out:
# Match found: abc

# %%
import re
result = re.match(r'abc', 'xyzabcdef')
if result:
    print("Match found:", result.group())
else:
    print("No match.")
# Out:
# No match.

# %% [markdown]
# # **2.	re.search(pattern, string):**
#
# ---
#
#
# o	Searches the entire string for the first occurrence of the pattern.
#
# o	Returns a match object if found, or None if not.
#
# o	Example:

# %%
result = re.search(r'abc', 'xyzabcdef')
if result:
    print("Match found:", result.group())
# Out:
# Match found: abc

# %% [markdown]
# # **3.	re.findall(pattern, string):**
#
# ---
#
#
# o	Finds all non-overlapping matches of the pattern in the string and returns them as a list.
#
# o	Example:

# %%
myres = re.findall(r'\d+', '2 abc 123 def 456')
print(myres)  # Output: ['123', '456']
# Out:
# ['2', '123', '456']

# %% [markdown]
# # **4.	re.sub(pattern, replacement, string):**
#
# ---
#
#
# o	Replaces all occurrences of the pattern in the string with the specified replacement.
#
# o	Example:

# %%
result = re.sub(r'\d+', 'demo', 'abc 123 def 456')
print(result)  # Output: abc X def X
# Out:
# abc demo def demo

# %% [markdown]
# # **5.	re.split(pattern, string):**
#
# ---
#
#
# o	Splits the string by the occurrences of the pattern.
#
# o	Example:

# %%
result = re.split(r'\s+', 'This is a test')
print(result)  # Output: ['This', 'is', 'a', 'test']
# Out:
# ['This', 'is', 'a', 'test']

# %% [markdown]
# # **3. Search and Replace**
#
# One common operation with regular expressions is searching for specific patterns in text and replacing them with new text. This can be achieved using re.sub(), which takes the following form:

# %%
import re
text = "I like cats and dogs"
text = re.sub(r'cats', 'pets', text)
print(text)  # Output: I like pets and dogs
# Out:
# I like pets and dogs

# %%
text
# Out:
# 'I like pets and dogs'

# %% [markdown]
# **Example 2: Replacing multiple spaces with a single space**
#
# ---

# %%
import re
text = "This  is  an   example."
new_text = re.sub(r'\s+', ' ', text)
print(new_text)  # Output: This is an example.
# Out:
# This is an example.

# %% [markdown]
# # **4. Compiling Regular Expression Patterns**
#
# ---
#
#
# Compiling a regular expression pattern allows you to optimize it by creating a compiled version of the regex. This is especially useful when the same pattern is used repeatedly in a program.
#
# To compile a pattern:

# %%
pattern = re.compile(r'\d+')

# %%
import re
pattern = re.compile(r'\d+')
text = "There are 123 apples and 456 oranges 5666."
result = pattern.findall(text)
print(result)  # Output: ['123', '456']
# Out:
# ['123', '456', '5666']
